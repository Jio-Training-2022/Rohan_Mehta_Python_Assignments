# %%
# Define Classes

# 1. User
class User:
    def __init__(self, name, age, gender, region):
        self.name = name
        self.age = age 
        self.gender = gender 
        self.region = region 

# 2. Product
class Product:
    def __init__(self, name, category, price):
        self.name = name
        self.category = category 
        self.price = price
        
# 3. Cart
class Cart:
    def __init__(self, user_id, items_count, cost, time):
        self.user_id = user_id
        self.items_count = items_count 
        self.cost = cost
        self.time = time
        
# 4. Website
class Website:
    def __init__(self, url, domain, footfall, avg_time):
        self.url = url
        self.domain = domain 
        self.footfall = footfall
        self.avg_time = avg_time
        
# 5. Movie
class Movie:
    def __init__(self, name, lead_actor, lead_actress, cost, release_date):
        self.name = name
        self.lead_actor = lead_actor 
        self.lead_actress = lead_actor
        self.cost = cost
        self.release_date = release_date
        
# 6. ProgrammingLanguage
class ProgrammingLanguage:
    def __init__(self, name, requirements, primitive_language):
        self.name = name
        self.requirements = requirements 
        self.primitive_language = primitive_language

# 7. Car
class Car:
    def __init__(self, company, model, suv, sedan, wheel_drive, CC, colour):
        self.company = company
        self.model = model 
        self.suv = sedan
        self.sedan = cost
        self.wheel_drive = wheel_drive
        self.CC = CC
        slef.colour = colour
        
# 8. Element
class Element:
    def __init__(self, name, symbol, atomic_no, atomic_mass, metal):
        self.name = name
        self.symbol = symbol 
        self.atomic_no = atomic_no
        self.atomic_mass = atomic_mass
        self.metal = metal
        
# 9. Building
class Building:
    def __init__(self, name, residential, floors, room_per_floor, lift, garden, parking):
        self.name = name
        self.residential = residential 
        self.floors = floors
        self.room_per_floor = room_per_floor
        self.lift = lift
        elf.garden = garden 
        self.parking = parking
        
# 10. City
class City:
    def __init__(self, name, state, country, area, population, airport):
        self.name = name
        self.state = state 
        self.country = country
        self.area = area
        self.population = population
        elf.airport = airport
        
# 11. Fruit
class Fruit:
    def __init__(self, name, colour, taste, season):
        self.name = name
        self.colour = colour 
        self.taste = taste
        self.area = area
        self.population = population
        elf.airport = airport

# %%
# Identify the classes in following Systems

# 1. Banking System
'''
account_no :: str
account_holder :: str
balance :: float
nominee :: str
is_joint_account :: Bool
debit_card_issued :: Bool
cheque_book_issued :: Bool
'''

# Schooling System
'''
students_count :: int
students_no :: int
student_name :: str
student_gender :: str
student_age :: int
classes_count :: int
divisions_count :: int
'''

# Hospital
'''
name :: str
patient_id :: int
patient_name :: str
patient_gender :: str
rooms_count :: int
'''

# Organisation
'''
name :: str
employee_count :: int
employee_id :: int
employee_name :: str
employee_gender :: str
region :: str
vendor :: str
customer :: str
'''

# EdTech System ( online only )
'''
name :: str
student_region :: str
students_count :: int
students_no :: int
student_name :: str
student_gender :: str
student_age :: int
classes_count :: int
divisions_count :: int
'''

# %%
# Identify the classes in following RealWorld Systems

#Instagram
'''
user_name :: str
user_id :: int
user_gender :: str
user_age :: int
user_region :: str
user_use_time :: float
user_posts_count :: int
user_friends_count :: int
'''
    
#Netflix
'''
user_name :: str
user_id :: int
user_gender :: str
user_age :: int
user_region :: str
user_use_time :: float
content_count :: int
'''

# LinkedIn
'''
user_name :: str
user_id :: int
user_gender :: str
user_age :: int
user_region :: str
user_use_time :: float
user_posts_count :: int
user_friends_count :: int
'''

Uber
'''
user_name :: str
user_id :: int
user_gender :: str
user_age :: int
user_region :: str
driver_name :: str
driver_id :: int
driver_gender :: str
driver_age :: int
driver_region :: str
driver_count :: int
'''

Zomato
'''
user_name :: str
user_id :: int
user_gender :: str
user_age :: int
user_region :: str
driver_name :: str
driver_id :: int
driver_gender :: str
driver_age :: int
driver_region :: str
restaurant_name :: str
restaurant_count :: int
'''

# %%
# Classes: Dealing with Complex Numbers

import math

class Complex(object):
    def __init__(self, real, imaginary):
        self.real = real
        self.imaginary = imaginary
    def __add__(self, no):
        return Complex(self.real + no.real, self.imaginary + no.imaginary)
    def __sub__(self, no):
        return Complex(self.real - no.real, self.imaginary - no.imaginary)
    def __mul__(self, no):
        return Complex((self.real * no.real - self.imaginary * no.imaginary), (self.real * no.imaginary + self.imaginary * no.real))
    def __truediv__(self, no):
        return Complex(((self.real * no.real + self.imaginary * no.imaginary)/(no.real ** 2 + no.imaginary ** 2)), ((self.imaginary * no.real - self.real * no.imaginary)/(no.real ** 2 + no.imaginary ** 2)))
    def mod(self):
        return Complex((self.real ** 2 + self.imaginary ** 2)**0.5, 0)
    def __str__(self):
        if self.imaginary == 0:
            result = "%.2f+0.00i" % (self.real)
        elif self.real == 0:
            if self.imaginary >= 0:
                result = "0.00+%.2fi" % (self.imaginary)
            else:
                result = "0.00-%.2fi" % (abs(self.imaginary))
        elif self.imaginary > 0:
            result = "%.2f+%.2fi" % (self.real, self.imaginary)
        else:
            result = "%.2f-%.2fi" % (self.real, abs(self.imaginary))
        return result

if __name__ == '__main__':
    c = map(float, input().split())
    d = map(float, input().split())
    x = Complex(*c)
    y = Complex(*d)
    print(*map(str, [x+y, x-y, x*y, x/y, x.mod(), y.mod()]), sep='\n')

# %%
# Find the Torsional Angle

import math

class Points(object):
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
    def __sub__(self, no):
        return  Points((self.x-no.x), (self.y-no.y), (self.z-no.z))
    def dot(self, no):
        return (self.x*no.x)+(self.y*no.y)+(self.z*no.z)
    def cross(self, no):
        return Points((self.y*no.z-self.z*no.y), (self.z*no.x-self.x*no.z), (self.x*no.y-self.y*no.x))
    def absolute(self):
        return pow((self.x ** 2 + self.y ** 2 + self.z ** 2), 0.5)

if __name__ == '__main__':
    points = list()
    for i in range(4):
        a = list(map(float, input().split()))
        points.append(a)

    a, b, c, d = Points(*points[0]), Points(*points[1]), Points(*points[2]), Points(*points[3])
    x = (b - a).cross(c - b)
    y = (c - b).cross(d - c)
    angle = math.acos(x.dot(y) / (x.absolute() * y.absolute()))

    print("%.2f" % math.degrees(angle))
# Out:
# 0 4 5
# 1 7 6
# 0 5 9
# 1 7 2
# 8.19
